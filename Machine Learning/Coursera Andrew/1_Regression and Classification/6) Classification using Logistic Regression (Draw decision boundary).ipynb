# %%
import numpy as np
import matplotlib.pyplot as plt

n = 30//2
np.random.seed(3)
x1 = np.append(1.5*np.random.random(n),2+2*np.random.random(n))
x2 = np.append(1.5*np.random.random(n),2+2*np.random.random(n))

y = np.append(np.zeros(n),np.ones(n))

w = np.array([1,1])  # Given that model params is known
b = 3                # Given that model params is known

db_x = np.linspace(0,3,25)
db_y = 3-db_x 
plt.figure(figsize=(8,5))
plt.scatter(x1,x2,c =y)
plt.plot(db_x, db_y, label='Decision Boundary', c = 'k')
plt.annotate('Decision Boundary', xy=(1.5, 1.5), xytext=(2.5, 1.5), # Predefined by help of ChatGPT
             arrowprops=dict(arrowstyle='->', color='k'))
plt.legend()
plt.show()
