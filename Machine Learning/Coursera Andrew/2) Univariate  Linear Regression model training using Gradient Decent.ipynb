# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(10)
noise = 5*np.random.randn(20)

x = np.arange(0,10,0.5)
y = x**2 + noise

plt.figure(figsize=(10,5))
plt.scatter(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
def cost_function(w,b):
    return (((w*x+b-y)**2).sum())/m


def gradient_decent(w,b):
    w_temp = w - alpha*(((w*x+b-y)*x).sum())/m
    b_temp = b - alpha*((w*x+b-y).sum())/m
    w = w_temp
    b = b_temp
    return w,b

alpha = 0.02
w = 1
b = 1
m = len(x)
cost = np.array([cost_function(w,b)])
iterations = np.array([1])

w,b = gradient_decent(w,b)
cost = np.append(cost,cost_function(w,b))
iteration = 1
iterations = np.append(iterations,iteration)

while (abs(cost[-2]-cost_function(w,b))>0.0000000000000000001): # Keep running until get only less of 0.0000000000000000001 improvement!
    w,b = gradient_decent(w,b)
    cost = np.append(cost,cost_function(w,b))
    iteration += 1
    iterations = np.append(iterations,iteration)

    
    
plt.figure(figsize=(10,5))
plt.scatter(x,y, label = 'Actual')
plt.plot(x,w*x+b, label = 'Linear Fit', c = 'k')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Fit Curve')
plt.legend()
plt.grid()
plt.show()



plt.figure(figsize=(10,5))
plt.plot(iterations,cost, label = 'Cost Function')
plt.xlabel('Iteration')
plt.ylabel('Cost function')
plt.title('Learning Curve')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x.reshape((20,1)),y)

print(f'sklearn model params ==> {model.coef_[0]:.4f} {model.intercept_:.4f}')
print(f'Gradient Decent parm ==> {w:.4f} {b:.4f}// {iteration} iterations')
# Out:
# sklearn model params ==> 9.4141 -13.2485
# Gradient Decent parm ==> 9.4141 -13.2485// 2846 iterations
